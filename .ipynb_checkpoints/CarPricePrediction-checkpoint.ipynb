# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df= pd.read_csv('pakwheels_data.csv')
df
# Out:
#          Ad No                                        Name  \
# 0      4096758                      Toyota Vitz F 1.0 2017
# 1      4168305  Toyota Corolla GLi Automatic 1.3 VVTi 2019
# 2      4168298                        Suzuki Alto VXL 2019
# 3      4168307                        Suzuki Alto VXR 2019
# 4      4168306                Toyota Corolla XLi VVTi 2010
# ...        ...                                         ...
# 56181  3349017   Honda Civic VTi Prosmatec 1.8 i-VTEC 2015
# 56182  3722322                           Toyota Prius 2015
# 56183  3748215                          Toyota Aqua G 2016
# 56184  3785520                   Honda Vezel Hybrid Z 2015
# 56185  3806951  Toyota Corolla GLi Automatic 1.3 VVTi 2015
#
#                     Price  Model Year                          Location  \
# 0               2385000.0        2017         G- 8, Islamabad Islamabad
# 1      111000.00000000001        2019                      Peshawar KPK
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
x = df.isnull().sum()
x
# Out:
# Ad No                 0
# Name                  0
# Price                 0
# Model Year            0
# Location              0
# Mileage               0
# Registered City       0
# Engine Type        1282
# Engine Capacity       0
# Transmission          0
# Color                 0
# Assembly              0
# Body Type          6469
# Features           5421
# Last Updated          0
# URL                   0
# dtype: int64

# %%
del df['URL']

# %%
df.columns
# Out:
# Index(['Ad No', 'Name', 'Price', 'Model Year', 'Location', 'Mileage',
#        'Registered City', 'Engine Type', 'Engine Capacity', 'Transmission',
#        'Color', 'Assembly', 'Body Type', 'Features', 'Last Updated'],
#       dtype='object')

# %%
df[df['Body Type'].isnull()]
# Out:
#          Ad No                           Name              Price  Model Year  \
# 12     4168314              Toyota Passo 2010          1470000.0        2010
# 29     4168251               Honda Civic 2007          1850000.0        2007
# 46     4168279               Honda Civic 2001  819999.9999999999        2001
# 76     4168238            Daihatsu Hijet 2013          1120000.0        2013
# 79     4168249        Daihatsu Mira Gino 2014          1490000.0        2014
# ...        ...                            ...                ...         ...
# 56173  4104207  Nissan Dayz Highway Star 2014          1500000.0        2014
# 56176  3705047            Toyota Corolla 1990           500000.0        1990
# 56177  3554707              Toyota Passo 2015          1870000.0        2015
# 56180  3339018                Nissan Kix 2012          1900000.0        2012
# 56182  3722322              Toyota Prius 2015          4000000.0        2015
#
# ...

# %%
x = df['Engine Type'].isnull()
x[x]
# Out:
# 175      True
# 215      True
# 220      True
# 440      True
# 944      True
#          ...
# 54759    True
# 54788    True
# 54796    True
# 54797    True
# 55230    True
# Name: Engine Type, Length: 1282, dtype: bool

# %%
df.dropna()
# Out:
#          Ad No                                        Name  \
# 0      4096758                      Toyota Vitz F 1.0 2017
# 1      4168305  Toyota Corolla GLi Automatic 1.3 VVTi 2019
# 2      4168298                        Suzuki Alto VXL 2019
# 3      4168307                        Suzuki Alto VXR 2019
# 4      4168306                Toyota Corolla XLi VVTi 2010
# ...        ...                                         ...
# 56179  3737684                          Toyota Aqua S 2015
# 56181  3349017   Honda Civic VTi Prosmatec 1.8 i-VTEC 2015
# 56183  3748215                          Toyota Aqua G 2016
# 56184  3785520                   Honda Vezel Hybrid Z 2015
# 56185  3806951  Toyota Corolla GLi Automatic 1.3 VVTi 2015
#
#                     Price  Model Year                          Location  \
# 0               2385000.0        2017         G- 8, Islamabad Islamabad
# 1      111000.00000000001        2019                      Peshawar KPK
# ...

# %%
df.Name.unique()
# Out:
# array(['Toyota Vitz F 1.0 2017',
#        'Toyota Corolla GLi Automatic 1.3 VVTi 2019',
#        'Suzuki Alto VXL 2019', ..., 'Honda Vamos Hobio G 2011',
#        'Toyota Prado TX Limited 3.4 2006', 'Chevrolet Camaro 2014'],
#       dtype=object)

# %%
df['Name'] = df.Name.apply(lambda x : x[:-4])

# %%
df.head()
# Out:
#      Ad No                                    Name               Price  \
# 0  4096758                      Toyota Vitz F 1.0            2385000.0
# 1  4168305  Toyota Corolla GLi Automatic 1.3 VVTi   111000.00000000001
# 2  4168298                        Suzuki Alto VXL            1530000.0
# 3  4168307                        Suzuki Alto VXR            1650000.0
# 4  4168306                Toyota Corolla XLi VVTi            1435000.0
#
#    Model Year                          Location  Mileage Registered City  \
# 0        2017         G- 8, Islamabad Islamabad     9869   Un-Registered
# 1        2019                      Peshawar KPK    11111       Islamabad
# 2        2019       Akora Khattak, Nowshera KPK    17500   Un-Registered
# 3        2019    Abdullahpur, Faisalabad Punjab     9600          Lahore
# 4        2010   9th Avenue, Islamabad Islamabad   120000       Islamabad
#
#   Engine Type Engine Capacity Transmission   Color  Assembly  Body Type  \
# ...

# %%
df.drop('Features', axis=1, inplace=True)

# %%
df
# Out:
#          Ad No                                    Name               Price  \
# 0      4096758                      Toyota Vitz F 1.0            2385000.0
# 1      4168305  Toyota Corolla GLi Automatic 1.3 VVTi   111000.00000000001
# 2      4168298                        Suzuki Alto VXL            1530000.0
# 3      4168307                        Suzuki Alto VXR            1650000.0
# 4      4168306                Toyota Corolla XLi VVTi            1435000.0
# ...        ...                                     ...                 ...
# 56181  3349017   Honda Civic VTi Prosmatec 1.8 i-VTEC            3250000.0
# 56182  3722322                           Toyota Prius            4000000.0
# 56183  3748215                          Toyota Aqua G            3000000.0
# 56184  3785520                   Honda Vezel Hybrid Z       Call for price
# 56185  3806951  Toyota Corolla GLi Automatic 1.3 VVTi            2250000.0
#
# ...

# %%
del df['Last Updated']

# %%
df.dropna(inplace=True)

# %%
df.columns
# Out:
# Index(['Ad No', 'Name', 'Price', 'Model Year', 'Location', 'Mileage',
#        'Registered City', 'Engine Type', 'Engine Capacity', 'Transmission',
#        'Color', 'Assembly', 'Body Type', 'Features', 'Last Updated', 'URL'],
#       dtype='object')

# %%
del df['URL']
del df['Last Updated']
del df['Features']

# %%
df.shape
# Out:
# (56186, 13)

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Ad No              0
# Name               0
# Price              0
# Model Year         0
# Location           0
# Mileage            0
# Registered City    0
# Engine Type        0
# Engine Capacity    0
# Transmission       0
# Color              0
# Assembly           0
# Body Type          0
# dtype: int64

# %%
del df['Ad No']

# %%
df.head()
# Out:
#                                          Name               Price  Model Year  \
# 0                      Toyota Vitz F 1.0 2017           2385000.0        2017
# 1  Toyota Corolla GLi Automatic 1.3 VVTi 2019  111000.00000000001        2019
# 2                        Suzuki Alto VXL 2019           1530000.0        2019
# 3                        Suzuki Alto VXR 2019           1650000.0        2019
# 4                Toyota Corolla XLi VVTi 2010           1435000.0        2010
#
#                            Location  Mileage Registered City Engine Type  \
# 0         G- 8, Islamabad Islamabad     9869   Un-Registered      Petrol
# 1                      Peshawar KPK    11111       Islamabad      Petrol
# 2       Akora Khattak, Nowshera KPK    17500   Un-Registered      Petrol
# 3    Abdullahpur, Faisalabad Punjab     9600          Lahore      Petrol
# 4   9th Avenue, Islamabad Islamabad   120000       Islamabad      Petrol
#
# ...

# %%
print(df.Name.unique())
# Out:
# ['Toyota Vitz F 1.0 2017' 'Toyota Corolla GLi Automatic 1.3 VVTi 2019'
#  'Suzuki Alto VXL 2019' ... 'Changan Kalash Base Grade 2014'
#  'Honda Vamos Hobio G 2011' 'Toyota Prado TX Limited 3.4 2006']

# %%
df['Name'] = df.Name.apply(lambda x: x[:-4])
# Out:
# C:\Users\maria\AppData\Local\Temp\ipykernel_11060\1401991645.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Name'] = df.Name.apply(lambda x: x[:-4])

# %%
df
# Out:
#                                          Name               Price  Model Year  \
# 0                          Toyota Vitz F 1.0            2385000.0        2017
# 1      Toyota Corolla GLi Automatic 1.3 VVTi   111000.00000000001        2019
# 2                            Suzuki Alto VXL            1530000.0        2019
# 3                            Suzuki Alto VXR            1650000.0        2019
# 4                    Toyota Corolla XLi VVTi            1435000.0        2010
# ...                                       ...                 ...         ...
# 56179                          Toyota Aqua S            2450000.0        2015
# 56181   Honda Civic VTi Prosmatec 1.8 i-VTEC            3250000.0        2015
# 56183                          Toyota Aqua G            3000000.0        2016
# 56184                   Honda Vezel Hybrid Z       Call for price        2015
# 56185  Toyota Corolla GLi Automatic 1.3 VVTi            2250000.0        2015
#
# ...

# %%
print(df.corr())
# Out:
#             Model Year   Mileage
# Model Year    1.000000 -0.609501
# Mileage      -0.609501  1.000000

# %%
sns.set()

# %%
plt.figure(figsize=(10,4))
sns.distplot(df.Price)
# Out:
# C:\Users\maria\AppData\Local\Temp\ipykernel_11060\4160016021.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Price)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [125], in <cell line: 2>()
#       1 plt.figure(figsize=(10,4))
# ----> 2 sns.distplot(df.Price)
#
# File c:\users\maria\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2464, in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48753 entries, 0 to 56185
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             48753 non-null  object
#  1   Price            48753 non-null  object
#  2   Model Year       48753 non-null  int64
#  3   Location         48753 non-null  object
#  4   Mileage          48753 non-null  int64
#  5   Registered City  48753 non-null  object
#  6   Engine Type      48753 non-null  object
#  7   Engine Capacity  48753 non-null  object
#  8   Transmission     48753 non-null  object
#  9   Color            48753 non-null  object
#  10  Assembly         48753 non-null  object
#  11  Body Type        48753 non-null  object
# dtypes: int64(2), object(10)
# memory usage: 4.8+ MB

# %%
df['Price']
# Out:
# 0                 2385000.0
# 1        111000.00000000001
# 2                 1530000.0
# 3                 1650000.0
# 4                 1435000.0
#                 ...
# 56179             2450000.0
# 56181             3250000.0
# 56183             3000000.0
# 56184        Call for price
# 56185             2250000.0
# Name: Price, Length: 48753, dtype: object

# %%
df.at[56184, 'Price'] = '0.000'

# %%
x = df['Price'] == 'Call for Price'
