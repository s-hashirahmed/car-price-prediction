# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df= pd.read_csv('pakwheels_data.csv')
df
# Out:
#          Ad No                                        Name  \
# 0      4096758                      Toyota Vitz F 1.0 2017
# 1      4168305  Toyota Corolla GLi Automatic 1.3 VVTi 2019
# 2      4168298                        Suzuki Alto VXL 2019
# 3      4168307                        Suzuki Alto VXR 2019
# 4      4168306                Toyota Corolla XLi VVTi 2010
# ...        ...                                         ...
# 56181  3349017   Honda Civic VTi Prosmatec 1.8 i-VTEC 2015
# 56182  3722322                           Toyota Prius 2015
# 56183  3748215                          Toyota Aqua G 2016
# 56184  3785520                   Honda Vezel Hybrid Z 2015
# 56185  3806951  Toyota Corolla GLi Automatic 1.3 VVTi 2015
#
#                     Price  Model Year                          Location  \
# 0               2385000.0        2017         G- 8, Islamabad Islamabad
# 1      111000.00000000001        2019                      Peshawar KPK
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
x = df.isnull().sum()
x
# Out:
# Ad No                 0
# Name                  0
# Price                 0
# Model Year            0
# Location              0
# Mileage               0
# Registered City       0
# Engine Type        1282
# Engine Capacity       0
# Transmission          0
# Color                 0
# Assembly              0
# Body Type          6469
# Features           5421
# Last Updated          0
# URL                   0
# dtype: int64

# %%
del df['URL']

# %%
df.columns
# Out:
# Index(['Ad No', 'Name', 'Price', 'Model Year', 'Location', 'Mileage',
#        'Registered City', 'Engine Type', 'Engine Capacity', 'Transmission',
#        'Color', 'Assembly', 'Body Type', 'Features', 'Last Updated'],
#       dtype='object')

# %%
df[df['Body Type'].isnull()]
# Out:
#          Ad No                           Name              Price  Model Year  \
# 12     4168314              Toyota Passo 2010          1470000.0        2010
# 29     4168251               Honda Civic 2007          1850000.0        2007
# 46     4168279               Honda Civic 2001  819999.9999999999        2001
# 76     4168238            Daihatsu Hijet 2013          1120000.0        2013
# 79     4168249        Daihatsu Mira Gino 2014          1490000.0        2014
# ...        ...                            ...                ...         ...
# 56173  4104207  Nissan Dayz Highway Star 2014          1500000.0        2014
# 56176  3705047            Toyota Corolla 1990           500000.0        1990
# 56177  3554707              Toyota Passo 2015          1870000.0        2015
# 56180  3339018                Nissan Kix 2012          1900000.0        2012
# 56182  3722322              Toyota Prius 2015          4000000.0        2015
#
# ...

# %%
x = df['Engine Type'].isnull()
x[x]
# Out:
# 175      True
# 215      True
# 220      True
# 440      True
# 944      True
#          ...
# 54759    True
# 54788    True
# 54796    True
# 54797    True
# 55230    True
# Name: Engine Type, Length: 1282, dtype: bool

# %%
df.dropna()
# Out:
#          Ad No                                        Name  \
# 0      4096758                      Toyota Vitz F 1.0 2017
# 1      4168305  Toyota Corolla GLi Automatic 1.3 VVTi 2019
# 2      4168298                        Suzuki Alto VXL 2019
# 3      4168307                        Suzuki Alto VXR 2019
# 4      4168306                Toyota Corolla XLi VVTi 2010
# ...        ...                                         ...
# 56179  3737684                          Toyota Aqua S 2015
# 56181  3349017   Honda Civic VTi Prosmatec 1.8 i-VTEC 2015
# 56183  3748215                          Toyota Aqua G 2016
# 56184  3785520                   Honda Vezel Hybrid Z 2015
# 56185  3806951  Toyota Corolla GLi Automatic 1.3 VVTi 2015
#
#                     Price  Model Year                          Location  \
# 0               2385000.0        2017         G- 8, Islamabad Islamabad
# 1      111000.00000000001        2019                      Peshawar KPK
# ...

# %%
df.Name.unique()
# Out:
# array(['Toyota Vitz F 1.0 2017',
#        'Toyota Corolla GLi Automatic 1.3 VVTi 2019',
#        'Suzuki Alto VXL 2019', ..., 'Honda Vamos Hobio G 2011',
#        'Toyota Prado TX Limited 3.4 2006', 'Chevrolet Camaro 2014'],
#       dtype=object)

# %%
df['Name'] = df.Name.apply(lambda x : x[:-4])

# %%
df.head()
# Out:
#      Ad No                                    Name               Price  \
# 0  4096758                      Toyota Vitz F 1.0            2385000.0
# 1  4168305  Toyota Corolla GLi Automatic 1.3 VVTi   111000.00000000001
# 2  4168298                        Suzuki Alto VXL            1530000.0
# 3  4168307                        Suzuki Alto VXR            1650000.0
# 4  4168306                Toyota Corolla XLi VVTi            1435000.0
#
#    Model Year                          Location  Mileage Registered City  \
# 0        2017         G- 8, Islamabad Islamabad     9869   Un-Registered
# 1        2019                      Peshawar KPK    11111       Islamabad
# 2        2019       Akora Khattak, Nowshera KPK    17500   Un-Registered
# 3        2019    Abdullahpur, Faisalabad Punjab     9600          Lahore
# 4        2010   9th Avenue, Islamabad Islamabad   120000       Islamabad
#
#   Engine Type Engine Capacity Transmission   Color  Assembly  Body Type  \
# ...

# %%
df.drop('Features', axis=1, inplace=True)

# %%
df
# Out:
#          Ad No                                    Name               Price  \
# 0      4096758                      Toyota Vitz F 1.0            2385000.0
# 1      4168305  Toyota Corolla GLi Automatic 1.3 VVTi   111000.00000000001
# 2      4168298                        Suzuki Alto VXL            1530000.0
# 3      4168307                        Suzuki Alto VXR            1650000.0
# 4      4168306                Toyota Corolla XLi VVTi            1435000.0
# ...        ...                                     ...                 ...
# 56181  3349017   Honda Civic VTi Prosmatec 1.8 i-VTEC            3250000.0
# 56182  3722322                           Toyota Prius            4000000.0
# 56183  3748215                          Toyota Aqua G            3000000.0
# 56184  3785520                   Honda Vezel Hybrid Z       Call for price
# 56185  3806951  Toyota Corolla GLi Automatic 1.3 VVTi            2250000.0
#
# ...

# %%
del df['Last Updated']

# %%
df.dropna(inplace=True)

# %%
df.columns
# Out:
# Index(['Ad No', 'Name', 'Price', 'Model Year', 'Location', 'Mileage',
#        'Registered City', 'Engine Type', 'Engine Capacity', 'Transmission',
#        'Color', 'Assembly', 'Body Type'],
#       dtype='object')

# %%
# del df['Last Updated']
# del df['Features']

# %%
df.shape
# Out:
# (48753, 13)

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Ad No              0
# Name               0
# Price              0
# Model Year         0
# Location           0
# Mileage            0
# Registered City    0
# Engine Type        0
# Engine Capacity    0
# Transmission       0
# Color              0
# Assembly           0
# Body Type          0
# dtype: int64

# %%
del df['Ad No']

# %%
df.head()
# Out:
#                                      Name               Price  Model Year  \
# 0                      Toyota Vitz F 1.0            2385000.0        2017
# 1  Toyota Corolla GLi Automatic 1.3 VVTi   111000.00000000001        2019
# 2                        Suzuki Alto VXL            1530000.0        2019
# 3                        Suzuki Alto VXR            1650000.0        2019
# 4                Toyota Corolla XLi VVTi            1435000.0        2010
#
#                            Location  Mileage Registered City Engine Type  \
# 0         G- 8, Islamabad Islamabad     9869   Un-Registered      Petrol
# 1                      Peshawar KPK    11111       Islamabad      Petrol
# 2       Akora Khattak, Nowshera KPK    17500   Un-Registered      Petrol
# 3    Abdullahpur, Faisalabad Punjab     9600          Lahore      Petrol
# 4   9th Avenue, Islamabad Islamabad   120000       Islamabad      Petrol
#
#   Engine Capacity Transmission   Color  Assembly  Body Type
# ...

# %%
print(df.Name.unique())
# Out:
# ['Toyota Vitz F 1.0 ' 'Toyota Corolla GLi Automatic 1.3 VVTi '
#  'Suzuki Alto VXL ' ... 'Jeep CJ 5 2.5 ' 'Honda N Box Moduro X G '
#  'Range Rover Vogue 5.0 V8 ']

# %%
df['Name'] = df.Name.apply(lambda x: x[:-4])

# %%
df
# Out:
#                                      Name               Price  Model Year  \
# 0                          Toyota Vitz F            2385000.0        2017
# 1      Toyota Corolla GLi Automatic 1.3 V  111000.00000000001        2019
# 2                            Suzuki Alto            1530000.0        2019
# 3                            Suzuki Alto            1650000.0        2019
# 4                    Toyota Corolla XLi V           1435000.0        2010
# ...                                   ...                 ...         ...
# 56179                          Toyota Aqu           2450000.0        2015
# 56181   Honda Civic VTi Prosmatec 1.8 i-V           3250000.0        2015
# 56183                          Toyota Aqu           3000000.0        2016
# 56184                   Honda Vezel Hybri      Call for price        2015
# 56185  Toyota Corolla GLi Automatic 1.3 V           2250000.0        2015
#
#                                Location  Mileage Registered City Engine Type  \
# ...

# %%
print(df.corr())
# Out:
#             Model Year   Mileage
# Model Year    1.000000 -0.609501
# Mileage      -0.609501  1.000000

# %%
sns.set()

# %%
# plt.figure(figsize=(10,4))
# sns.distplot(df.Price)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48753 entries, 0 to 56185
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             48753 non-null  object
#  1   Price            48753 non-null  object
#  2   Model Year       48753 non-null  int64
#  3   Location         48753 non-null  object
#  4   Mileage          48753 non-null  int64
#  5   Registered City  48753 non-null  object
#  6   Engine Type      48753 non-null  object
#  7   Engine Capacity  48753 non-null  object
#  8   Transmission     48753 non-null  object
#  9   Color            48753 non-null  object
#  10  Assembly         48753 non-null  object
#  11  Body Type        48753 non-null  object
# dtypes: int64(2), object(10)
# memory usage: 4.8+ MB

# %%
df['Price']
# Out:
# 0                 2385000.0
# 1        111000.00000000001
# 2                 1530000.0
# 3                 1650000.0
# 4                 1435000.0
#                 ...
# 56179             2450000.0
# 56181             3250000.0
# 56183             3000000.0
# 56184        Call for price
# 56185             2250000.0
# Name: Price, Length: 48753, dtype: object

# %%
# a = df[df['Price'] == 'Call for price'].index.to_list()

# x = df.index.isin(a)
# df.drop(df['Price'] == 'Call for price', axis='column')

# %%
x = df['Price'] == 'Call for Price'

# %%
x[x]
# Out:
# Series([], Name: Price, dtype: bool)

# %%
# df['Price']=df.Price.astype(float)
# plt.figure(figsize=(15,10))
# sns.distplot(df.Price)

# %%
x = df['Price'] == 'Call for price'
ind = x[x].index
df.drop(ind, inplace=True)
ind
# Out:
# Int64Index([   87,    89,    93,    97,   117,   118,   119,   125,   161,
#               162,
#             ...
#             55801, 55812, 55813, 55852, 55998, 55999, 56000, 56076, 56158,
#             56184],
#            dtype='int64', length=1188)

# %%
y = df.Price.values
# df = df.astype({'Price' : float})

df[df['Price'] == 'PKR 1,260']
df.drop(6465, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47564 entries, 0 to 56185
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             47564 non-null  object
#  1   Price            47564 non-null  object
#  2   Model Year       47564 non-null  int64
#  3   Location         47564 non-null  object
#  4   Mileage          47564 non-null  int64
#  5   Registered City  47564 non-null  object
#  6   Engine Type      47564 non-null  object
#  7   Engine Capacity  47564 non-null  object
#  8   Transmission     47564 non-null  object
#  9   Color            47564 non-null  object
#  10  Assembly         47564 non-null  object
#  11  Body Type        47564 non-null  object
# dtypes: int64(2), object(10)
# memory usage: 4.7+ MB

# %%
df.isnull().sum()
# Out:
# Name               0
# Price              0
# Model Year         0
# Location           0
# Mileage            0
# Registered City    0
# Engine Type        0
# Engine Capacity    0
# Transmission       0
# Color              0
# Assembly           0
# Body Type          0
# dtype: int64

# %%
df.groupby('Location').mean()['Mileage']
# Out:
# Location
#  ---, Larkana Sindh                     28766.500000
#  204 Chak Road, Faisalabad Punjab       81215.348837
#  29 Block, Sargodha Punjab             139233.909091
#  7th Avenue, Islamabad Islamabad        85300.922509
#  9th Avenue, Islamabad Islamabad        86971.569892
#                                            ...
#  Zero Point, Islamabad Islamabad        63938.956522
#  Zia Town, Faisalabad Punjab           127333.333333
#  Zone 5, Islamabad Islamabad           180000.000000
#  Zulfiqar Colony, Faisalabad Punjab    145000.000000
#  shams abad, Rawalpindi Punjab         113043.333333
# Name: Mileage, Length: 2076, dtype: float64

# %%
df.columns
# Out:
# Index(['Name', 'Price', 'Model Year', 'Location', 'Mileage', 'Registered City',
#        'Engine Type', 'Engine Capacity', 'Transmission', 'Color', 'Assembly',
#        'Body Type'],
#       dtype='object')

# %%
df.groupby('Engine Type').count()
# Out:
#               Name  Price  Model Year  Location  Mileage  Registered City  \
# Engine Type
# Diesel        1489   1489        1489      1489     1489             1489
# Hybrid        1539   1539        1539      1539     1539             1539
# Petrol       44536  44536       44536     44536    44536            44536
#
#              Engine Capacity  Transmission  Color  Assembly  Body Type
# Engine Type
# Diesel                  1489          1489   1489      1489       1489
# Hybrid                  1539          1539   1539      1539       1539
# Petrol                 44536         44536  44536     44536      44536

# %%
sns.heatmap(df.corr(), cmap='coolwarm', annot=True)
# Out:
# <AxesSubplot: >

# %%
df['Price'].dtype
# Out:
# dtype('O')

# %%
df.describe()
# Out:
#          Model Year        Mileage
# count  47564.000000   47564.000000
# mean    2011.295076   89867.111975
# std        6.246773   63206.163512
# min     1990.000000       1.000000
# 25%     2007.000000   47525.500000
# 50%     2013.000000   80000.000000
# 75%     2016.000000  120000.000000
# max     2019.000000  999999.000000

# %%
df['Engine Capacity']=df['Engine Capacity'].apply(lambda x:x[:-2])

# %%
df['Engine Capacity']=df['Engine Capacity'].astype('int64')
df['Engine Capacity']
# Out:
# 0        1000
# 1        1300
# 2         660
# 3         660
# 4        1300
#          ...
# 56178    1500
# 56179    1500
# 56181    1800
# 56183    1500
# 56185    1300
# Name: Engine Capacity, Length: 47564, dtype: int64

# %%
df.corr()
# Out:
#                  Model Year   Mileage  Engine Capacity
# Model Year         1.000000 -0.607066        -0.146468
# Mileage           -0.607066  1.000000         0.098604
# Engine Capacity   -0.146468  0.098604         1.000000

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(), cmap='coolwarm',annot=True)
# Out:
# <AxesSubplot: >

# %%
features = df.drop('Price',axis=1)
features
# Out:
#                                      Name  Model Year  \
# 0                          Toyota Vitz F         2017
# 1      Toyota Corolla GLi Automatic 1.3 V        2019
# 2                            Suzuki Alto         2019
# 3                            Suzuki Alto         2019
# 4                    Toyota Corolla XLi V        2010
# ...                                   ...         ...
# 56178                   Honda Vezel Hybri        2015
# 56179                          Toyota Aqu        2015
# 56181   Honda Civic VTi Prosmatec 1.8 i-V        2015
# 56183                          Toyota Aqu        2016
# 56185  Toyota Corolla GLi Automatic 1.3 V        2015
#
#                                Location  Mileage Registered City Engine Type  \
# 0             G- 8, Islamabad Islamabad     9869   Un-Registered      Petrol
# 1                          Peshawar KPK    11111       Islamabad      Petrol
# 2           Akora Khattak, Nowshera KPK    17500   Un-Registered      Petrol
# ...

# %%
from sklearn.model_selection import train_test_split


features=df.drop('Price', axis=1)
features

y = df['Price']
df['Price'] = df['Price'].astype('float64')


# X_train, X_test, y_train, y_test = train_test_split(x, y)


# X = df.drop('Price',axis=1)
# X
# X_train, Xtest, y_train, y_test = train_test_split(X, y)

# %%
df
# Out:
#                                      Name      Price  Model Year  \
# 0                          Toyota Vitz F   2385000.0        2017
# 1      Toyota Corolla GLi Automatic 1.3 V   111000.0        2019
# 2                            Suzuki Alto   1530000.0        2019
# 3                            Suzuki Alto   1650000.0        2019
# 4                    Toyota Corolla XLi V  1435000.0        2010
# ...                                   ...        ...         ...
# 56178                   Honda Vezel Hybri  3400000.0        2015
# 56179                          Toyota Aqu  2450000.0        2015
# 56181   Honda Civic VTi Prosmatec 1.8 i-V  3250000.0        2015
# 56183                          Toyota Aqu  3000000.0        2016
# 56185  Toyota Corolla GLi Automatic 1.3 V  2250000.0        2015
#
#                                Location  Mileage Registered City Engine Type  \
# 0             G- 8, Islamabad Islamabad     9869   Un-Registered      Petrol
# ...

# %%
df.corr()
# Out:
#                     Price  Model Year   Mileage  Engine Capacity
# Price            1.000000    0.214585 -0.185673         0.640496
# Model Year       0.214585    1.000000 -0.607066        -0.146468
# Mileage         -0.185673   -0.607066  1.000000         0.098604
# Engine Capacity  0.640496   -0.146468  0.098604         1.000000

# %%
y = df['Price']
x = df.drop('Price',axis=1)
x = x[['Model Year', 'Mileage', 'Engine Capacity']]

# %%
X_train
# Out:
#        Model Year  Mileage  Engine Capacity
# 17023        2011   115000             1600
# 47468        1995   119000             1500
# 33546        2006   110000             1000
# 48880        2011    74000             2500
# 18210        1992   190478             1300
# ...           ...      ...              ...
# 32362        2014    87000             1800
# 14074        2012    98000             1300
# 24452        2001   190000             4200
# 52849        2014    62000             1500
# 28802        2007   158000             1300
#
# [35673 rows x 3 columns]

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
prediction = model.predict(X_test)
prediction
# Out:
# array([ 671666.66666667, 1687500.        , 1411666.66666667, ...,
#        1900000.        , 1320000.        , 1502727.27272727])

# %%
y_test.index, X_test.index
# Out:
# (Int64Index([47373, 42648, 55668, 17566, 25151,  9256, 55255, 30421,  9579,
#              42958,
#              ...
#              46200,  1311, 53221, 25576,  2803, 16528,  4443, 24946, 29536,
#              22881],
#             dtype='int64', length=11891),
#  Int64Index([47373, 42648, 55668, 17566, 25151,  9256, 55255, 30421,  9579,
#              42958,
#              ...
#              46200,  1311, 53221, 25576,  2803, 16528,  4443, 24946, 29536,
#              22881],
#             dtype='int64', length=11891))

# %%
plt.plot(prediction)
y_test.index
# Out:
# Int64Index([47373, 42648, 55668, 17566, 25151,  9256, 55255, 30421,  9579,
#             42958,
#             ...
#             46200,  1311, 53221, 25576,  2803, 16528,  4443, 24946, 29536,
#             22881],
#            dtype='int64', length=11891)

# %%
names = df['Name'].unique()

# %% [markdown]
# names

# %%
df['Transmission']=df['Transmission'].apply(lambda x: x.strip())
df['Name']=df['Name'].apply(lambda x: x.strip())
df.Name.unique()
# Out:
# array(['Toyota Vitz F', 'Toyota Corolla GLi Automatic 1.3 V',
#        'Suzuki Alto', ..., 'Toyota Ractis 1', 'Jeep CJ 5',
#        'Range Rover Vogue 5.0'], dtype=object)

# %%
name = 'Suzuki Alto'
df['Model Year']=df['Model Year'].apply(lambda x: int(x))
df['Model Year'] = df['Model Year'].astype(int)
df
# print(df.Transmission.unique())
# df[df.Transmission == trans]
# Out:
#                                      Name      Price  Model Year  \
# 0                           Toyota Vitz F  2385000.0        2017
# 1      Toyota Corolla GLi Automatic 1.3 V   111000.0        2019
# 2                             Suzuki Alto  1530000.0        2019
# 3                             Suzuki Alto  1650000.0        2019
# 4                    Toyota Corolla XLi V  1435000.0        2010
# ...                                   ...        ...         ...
# 56178                   Honda Vezel Hybri  3400000.0        2015
# 56179                          Toyota Aqu  2450000.0        2015
# 56181   Honda Civic VTi Prosmatec 1.8 i-V  3250000.0        2015
# 56183                          Toyota Aqu  3000000.0        2016
# 56185  Toyota Corolla GLi Automatic 1.3 V  2250000.0        2015
#
#                                Location  Mileage Registered City Engine Type  \
# 0             G- 8, Islamabad Islamabad     9869   Un-Registered      Petrol
# ...

# %%
x = df[(df['Name']==name)]
x
x = x[x['Transmission'] == 'Automatic']
x
# Out:
#               Name      Price  Model Year  \
# 2      Suzuki Alto  1530000.0        2019
# 72     Suzuki Alto   700000.0        2008
# 673    Suzuki Alto  1550000.0        2019
# 848    Suzuki Alto   750000.0        2000
# 983    Suzuki Alto   420000.0        2006
# ...            ...        ...         ...
# 55432  Suzuki Alto  1550000.0        2019
# 55626  Suzuki Alto  1500000.0        2019
# 55782  Suzuki Alto  1550000.0        2019
# 55866  Suzuki Alto   700000.0        2007
# 55917  Suzuki Alto  1550000.0        2019
#
#                                         Location  Mileage Registered City  \
# 2                    Akora Khattak, Nowshera KPK    17500   Un-Registered
# 72      Lahore Sargodha Road, Shiekhopura Punjab   123000          Lahore
# 673                      Shadbagh, Lahore Punjab     7096          Lahore
# 848                          Cantt, Peshawar KPK   150000        Peshawar
# 983                    G- 7, Islamabad Islamabad   150000       Islamabad
# ...

# %%
x = x[x['Engine Type'] == 'Petrol']
x
# Out:
#               Name      Price  Model Year  \
# 2      Suzuki Alto  1530000.0        2019
# 72     Suzuki Alto   700000.0        2008
# 673    Suzuki Alto  1550000.0        2019
# 848    Suzuki Alto   750000.0        2000
# 983    Suzuki Alto   420000.0        2006
# ...            ...        ...         ...
# 55432  Suzuki Alto  1550000.0        2019
# 55626  Suzuki Alto  1500000.0        2019
# 55782  Suzuki Alto  1550000.0        2019
# 55866  Suzuki Alto   700000.0        2007
# 55917  Suzuki Alto  1550000.0        2019
#
#                                         Location  Mileage Registered City  \
# 2                    Akora Khattak, Nowshera KPK    17500   Un-Registered
# 72      Lahore Sargodha Road, Shiekhopura Punjab   123000          Lahore
# 673                      Shadbagh, Lahore Punjab     7096          Lahore
# 848                          Cantt, Peshawar KPK   150000        Peshawar
# 983                    G- 7, Islamabad Islamabad   150000       Islamabad
# ...

# %%
def get_df(name, trans, eng_type):
    x = df[(df['Name']==name)]
    x = x[x['Transmission'] == trans]
    x = x[x['Engine Type'] == eng_type]
    
    return x[['Model Year', 'Mileage', 'Engine Capacity']], x['Price']

name = 'Toyota Corolla GLi Automatic 1.3 V'
trans = 'Automatic'
eng_type = 'Petrol'

get_df(name, trans, eng_type)
# Out:
# (       Model Year  Mileage  Engine Capacity
#  1            2019    11111             1300
#  15           2018    51240             1300
#  49           2019    20000             1300
#  183          2017    38000             1300
#  212          2014    70000             1300
#  ...           ...      ...              ...
#  55495        2015   115000             1300
#  55528        2015    78000             1300
#  55652        2014   123488             1300
#  55901        2016    39000             1300
#  56185        2015    77000             1300
#
#  [714 rows x 3 columns],
#  1         111000.0
#  15       2750000.0
#  49       3000000.0
#  183      2480000.0
#  212      2075000.0
#             ...
#  55495    2150000.0
#  55528    2300000.0
#  55652    2250000.0
#  55901    2175000.0
#  56185    2250000.0
#  Name: Price, Length: 714, dtype: float64)

# %%
from sklearn.model_selection import train_test_split
x, y = get_df(name, trans, eng_type)

X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.2)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
# from sklearn.Linear_model import Linear
from sklearn.linear_model import LinearRegression
model_1 = DecisionTreeRegressor()
model_1.fit(X_train,y_train)

model_2 = SVR()
model_2.fit(X_train, y_train)

model_3 = LinearRegression().fit(X_train, y_train)

# %%
prediction_1 = model_1.predict([[2018,11111,1300]])
list(np.round(prediction_1,0))



# prediction_2 = model_2.predict(X_test)
# np.round(prediction_2,0)


# prediction_3 = model_3.predict(X_test)
# np.round(prediction_3,0)
# Out:
# c:\users\maria\appdata\local\programs\python\python39\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# [111000.0]

# %%
prediction_1 = model_1.predict(X_test)
pred = np.round(prediction_1,0)

# %%
y_test.values[25], pred[25]
# Out:
# (2780000.0, 2850000.0)

# %%
model_1.score(X_test, prediction_1)
# Out:
# 1.0

# %%
model_2.score(X_test, prediction_2)
# Out:
# 1.0

# %%
model_3.score(X_test, prediction_3)
# Out:
# 1.0

# %%
import pickle

pickle.dump(df, open('data.pkl','wb'))
